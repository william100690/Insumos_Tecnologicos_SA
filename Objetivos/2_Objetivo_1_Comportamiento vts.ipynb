# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#leer el archivo csv
df = pd.read_csv("C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/Venta.csv")

# %%
#mostrar archivo csv
df.head(5)
# Out:
#    IdVenta       Fecha Fecha_Entrega  IdCanal  IdCliente  IdSucursal  \
# 0        1  2018-03-09    2018-03-17        3        969          13
# 1        2  2018-12-28    2018-12-29        2        884          13
# 2        3  2016-03-28    2016-03-31        2       1722          13
# 3        4  2017-10-23    2017-10-24        3       2876          13
# 4        5  2017-11-22    2017-11-25        2        678          13
#
#    IdEmpleado  IdProducto  Precio  Cantidad
# 0        1674       42817  813.12       2.0
# 1        1674       42795  543.18       3.0
# 2        1674       42837  430.32       1.0
# 3        1674       42834  818.84       2.0
# 4        1674       42825  554.18       3.0

# %%
#verificar el tipo de dato de cada columna
df.dtypes
# Out:
# IdVenta            int64
# Fecha             object
# Fecha_Entrega     object
# IdCanal            int64
# IdCliente          int64
# IdSucursal         int64
# IdEmpleado         int64
# IdProducto         int64
# Precio           float64
# Cantidad         float64
# dtype: object

# %%
# cambiar el tipo de dato a tipo date time
df['Fecha'] = pd.to_datetime(df['Fecha'])

df.dtypes
# Out:
# IdVenta                   int64
# Fecha            datetime64[ns]
# Fecha_Entrega            object
# IdCanal                   int64
# IdCliente                 int64
# IdSucursal                int64
# IdEmpleado                int64
# IdProducto                int64
# Precio                  float64
# Cantidad                float64
# dtype: object

# %%
#obtener únicamente los años
años = df['Fecha'].dt.year.unique()
años.sort()
años
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
#ordenar el data frame por fecha
df = df.sort_values('Fecha')
df.head(3)
# Out:
#        IdVenta      Fecha Fecha_Entrega  IdCanal  IdCliente  IdSucursal  \
# 39353    39354 2015-01-01    2015-01-04        1        529          27
# 24818    24819 2015-01-01    2015-01-03        3       1112          17
# 13230    13231 2015-01-01    2015-01-04        3       1257           6
#
#        IdEmpleado  IdProducto  Precio  Cantidad
# 39353        3588       42824  584.76       2.0
# 24818        3172       42905  456.00       2.0
# 13230        1426       42906  321.00       2.0

# %%
#obtener las ventas al multiplicar la columna precio y cantidad
df['Ventas'] = df['Precio'] * df['Cantidad']
df.head(3)
# Out:
#        IdVenta      Fecha Fecha_Entrega  IdCanal  IdCliente  IdSucursal  \
# 39353    39354 2015-01-01    2015-01-04        1        529          27
# 24818    24819 2015-01-01    2015-01-03        3       1112          17
# 13230    13231 2015-01-01    2015-01-04        3       1257           6
#
#        IdEmpleado  IdProducto  Precio  Cantidad   Ventas
# 39353        3588       42824  584.76       2.0  1169.52
# 24818        3172       42905  456.00       2.0   912.00
# 13230        1426       42906  321.00       2.0   642.00

# %%
#crear un nuevo data frame con la suma de las ventas de cada fecha
df_Fecha_Ventas = df.groupby('Fecha')['Ventas'].sum().reset_index()

# %%
df_Fecha_Ventas['Ventas'] = df_Fecha_Ventas['Ventas'].astype(int)

# %%
#obtener un data frame por cada año
df_2015 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2015].copy()
df_2016 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2016].copy()
df_2017 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2017].copy()
df_2018 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2018].copy()
df_2019 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2019].copy()
df_2020 = df_Fecha_Ventas[df_Fecha_Ventas['Fecha'].dt.year == 2020].copy()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2015
plt.plot(df_2015['Fecha'], df_2015['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2015')

# Mostrar el gráfico
plt.show()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2016
plt.plot(df_2016['Fecha'], df_2016['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2016')

# Mostrar el gráfico
plt.show()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2017
plt.plot(df_2017['Fecha'], df_2017['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2017')

# Mostrar el gráfico
plt.show()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2018
plt.plot(df_2018['Fecha'], df_2018['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2018')

# Mostrar el gráfico
plt.show()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2019
plt.plot(df_2019['Fecha'], df_2019['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2019')

# Mostrar el gráfico
plt.show()

# %%
#obtner la grafica de comportamiento de las ventas en el año 2020
plt.plot(df_2020['Fecha'], df_2020['Ventas'])

# Configurar el eje X para mostrar las fechas de manera legible
plt.xticks(rotation=45)

# Etiquetas de los ejes
plt.xlabel('Fecha')
plt.ylabel('Ventas')

# Título del gráfico
plt.title('Ventas por Fecha 2020')

# Mostrar el gráfico
plt.show()

# %%
#guardar los data frames en archivos csv
df_2015.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2015.csv', index=False)
df_2016.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2016.csv', index=False)
df_2017.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2017.csv', index=False)
df_2018.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2018.csv', index=False)
df_2019.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2019.csv', index=False)
df_2020.to_csv('C:/Users/willi/OneDrive/Escritorio/Proyectos/Insumos_Tecnologicos_SA/Datasets/vts_2020.csv', index=False)

# %%
df_2020
# Out:
#           Fecha  Ventas
# 1559 2020-01-01  422411
# 1560 2020-01-02  893525
# 1561 2020-01-03  244899
# 1562 2020-01-04   49393
# 1563 2020-01-06   99919
# ...         ...     ...
# 1867 2020-12-25    2782
# 1868 2020-12-26   21924
# 1869 2020-12-28   29839
# 1870 2020-12-29   28708
# 1871 2020-12-30   28703
#
# [313 rows x 2 columns]
